# %% [markdown]
# 1. 플릭커 API를 통한 이미지 수집 및 라벨링
#  - www.flickr.com
#  - Yahoo.com 계정 생성 후에 Flickr API 페이지에 들어가서 생성
#  - https://www.flickr.com/services/api
#
#  - 화면 상단의 App 제작 또는 Create APP 클릭->비상업용 키 신청->App 이름 및 설명 입력 후 등록(submit)
#  - key, secret을 보관

# %%
# !pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading flickrapi-2.4.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from flickrapi) (1.16.0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from flickrapi) (2.31.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from flickrapi) (1.3.1)
# Collecting requests-toolbelt>=0.3.1 (from flickrapi)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->flickrapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->flickrapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->flickrapi) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->flickrapi) (2024.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.4.0->flickrapi) (3.2.2)
# Installing collected packages: requests-toolbelt, flickrapi
# Successfully installed flickrapi-2.4.0 requests-toolbelt-1.0.0

# %% [markdown]
# - 원하는 범주별 사진 수집, 각각의 폴더에 이미지 저장, 각 범주로 사진 분류
#  - 첫 번째 범주에 해당하는 이미지 수집

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

key="4ab84b4cfe4fedc4294d5aaa671eaca9"
secret="435260602baa2cb2"

wait_time=1

#사진 검색 및 저장
savedir="sushi"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="스시", per_page=50, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 13,
#  'perpage': 50,
#  'photo': [{'farm': 1,
#             'height_q': 150,
#             'id': '23334959815',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': '5b75a361fa',
#             'server': '707',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/707/23334959815_5b75a361fa_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22707816333',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'c7d4341133',
#             'server': '5803',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/5803/22707816333_c7d4341133_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '23039168170',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': '61bdf06962',
#             'server': '5742',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/5742/23039168170_61bdf06962_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '23226644172',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': '61387ae009',
#             'server': '691',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/691/23226644172_61387ae009_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '22967036439',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'f4e529cde5',
#             'server': '602',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/602/22967036439_f4e529cde5_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '23252384021',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': '7431ff72c1',
#             'server': '5809',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/5809/23252384021_7431ff72c1_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4613588369',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42807823@N08',
#             'secret': 'f20587cdc7',
#             'server': '4054',
#             'title': '오늘점심은 스시',
#             'url_q': 'https://live.staticflickr.com/4054/4613588369_f20587cdc7_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '23226643962',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'eab85be54c',
#             'server': '782',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/782/23226643962_eab85be54c_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '23252388091',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': '2cc79809cf',
#             'server': '5722',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/5722/23252388091_2cc79809cf_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '22967031779',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'bcf90a9c7a',
#             'server': '667',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/667/22967031779_bcf90a9c7a_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '23039174230',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'e66e1039ec',
#             'server': '5674',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/5674/23039174230_e66e1039ec_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '23226644912',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'ff2544b0db',
#             'server': '610',
#             'title': '스시 sushi',
#             'url_q': 'https://live.staticflickr.com/610/23226644912_ff2544b0db_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4485897969',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '31846612@N08',
#             'secret': '70ea22cb94',
#             'server': '4071',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/4071/4485897969_70ea22cb94_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2520058940',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '20796425@N00',
#             'secret': '5f4d2bdd31',
#             'server': '3089',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/3089/2520058940_5f4d2bdd31_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4413988768',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '44971549@N06',
#             'secret': '416d9b56c6',
#             'server': '4050',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/4050/4413988768_416d9b56c6_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '12046800576',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '101035667@N02',
#             'secret': '2b0ed02995',
#             'server': '3833',
#             'title': 'IMGP1844',
#             'url_q': 'https://live.staticflickr.com/3833/12046800576_2b0ed02995_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '12046843746',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '101035667@N02',
#             'secret': '9b1342bf81',
#             'server': '3705',
#             'title': 'IMGP6422 tumb',
#             'url_q': 'https://live.staticflickr.com/3705/12046843746_9b1342bf81_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413917783',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'f272f490cb',
#             'server': '3304',
#             'title': 'R0012464',
#             'url_q': 'https://live.staticflickr.com/3304/3413917783_f272f490cb_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317848',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'beef335422',
#             'server': '146',
#             'title': '롤',
#             'url_q': 'https://live.staticflickr.com/146/364317848_beef335422_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317858',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '460dcce0e4',
#             'server': '102',
#             'title': '새우스시',
#             'url_q': 'https://live.staticflickr.com/102/364317858_460dcce0e4_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317864',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'c67dacff6b',
#             'server': '164',
#             'title': '참치스시',
#             'url_q': 'https://live.staticflickr.com/164/364317864_c67dacff6b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '12046009365',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '101035667@N02',
#             'secret': '692b6624eb',
#             'server': '3713',
#             'title': 'IMGP6411 orig tumb',
#             'url_q': 'https://live.staticflickr.com/3713/12046009365_692b6624eb_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2519237785',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '20796425@N00',
#             'secret': 'da33b5ec91',
#             'server': '2194',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/2194/2519237785_da33b5ec91_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2384023607',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '24929240@N03',
#             'secret': '8289b9e51b',
#             'server': '2308',
#             'title': '우에노 스시집',
#             'url_q': 'https://live.staticflickr.com/2308/2384023607_8289b9e51b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4427476755',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '46577275@N02',
#             'secret': 'b8ddc1ac07',
#             'server': '2723',
#             'title': '알바시간이 다가온다. 아아 ..',
#             'url_q': 'https://live.staticflickr.com/2723/4427476755_b8ddc1ac07_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317862',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '7168bc5e1f',
#             'server': '157',
#             'title': '장어스시',
#             'url_q': 'https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2123838912',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '20796425@N00',
#             'secret': '218c6bfa54',
#             'server': '2297',
#             'title': '스시!',
#             'url_q': 'https://live.staticflickr.com/2297/2123838912_218c6bfa54_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '4561734849',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '23620468@N03',
#             'secret': 'da1878d0df',
#             'server': '3395',
#             'title': '스시!!',
#             'url_q': 'https://live.staticflickr.com/3395/4561734849_da1878d0df_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5736664674',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29904101@N08',
#             'secret': '5543df9be6',
#             'server': '2743',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/2743/5736664674_5543df9be6_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3027691038',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29904101@N08',
#             'secret': 'eb80a3f1c8',
#             'server': '3211',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/3211/3027691038_eb80a3f1c8_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6174382207',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29904101@N08',
#             'secret': '22678f4664',
#             'server': '6152',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/6152/6174382207_22678f4664_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414740364',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '7b0517f43b',
#             'server': '3541',
#             'title': 'R0012482',
#             'url_q': 'https://live.staticflickr.com/3541/3414740364_7b0517f43b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414727600',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'd14ae5eaea',
#             'server': '3616',
#             'title': 'R0012468',
#             'url_q': 'https://live.staticflickr.com/3616/3414727600_d14ae5eaea_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413932307',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'd9efd098fa',
#             'server': '3605',
#             'title': 'R0012480',
#             'url_q': 'https://live.staticflickr.com/3605/3413932307_d9efd098fa_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2519237511',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '20796425@N00',
#             'secret': 'f8b5e17c3e',
#             'server': '2404',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/2404/2519237511_f8b5e17c3e_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414728502',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '64c64d018d',
#             'server': '3561',
#             'title': 'R0012469',
#             'url_q': 'https://live.staticflickr.com/3561/3414728502_64c64d018d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413923087',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '38b0a8f7c3',
#             'server': '3589',
#             'title': 'R0012470',
#             'url_q': 'https://live.staticflickr.com/3589/3413923087_38b0a8f7c3_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414736660',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'f0fe1f53a0',
#             'server': '3022',
#             'title': 'R0012478',
#             'url_q': 'https://live.staticflickr.com/3022/3414736660_f0fe1f53a0_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414731218',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '13ccd5420a',
#             'server': '3324',
#             'title': 'R0012472',
#             'url_q': 'https://live.staticflickr.com/3324/3414731218_13ccd5420a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414735588',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'eb051f117d',
#             'server': '3356',
#             'title': 'R0012477',
#             'url_q': 'https://live.staticflickr.com/3356/3414735588_eb051f117d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413935469',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'c7f53de2e5',
#             'server': '3564',
#             'title': 'R0012483',
#             'url_q': 'https://live.staticflickr.com/3564/3413935469_c7f53de2e5_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413918637',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '80bded5c96',
#             'server': '3632',
#             'title': 'R0012465',
#             'url_q': 'https://live.staticflickr.com/3632/3413918637_80bded5c96_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413926755',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'cf8716c918',
#             'server': '3664',
#             'title': 'R0012474',
#             'url_q': 'https://live.staticflickr.com/3664/3413926755_cf8716c918_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414730260',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '2f344e871c',
#             'server': '3297',
#             'title': 'R0012471',
#             'url_q': 'https://live.staticflickr.com/3297/3414730260_2f344e871c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3413933397',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'f7856c518d',
#             'server': '3033',
#             'title': 'R0012481',
#             'url_q': 'https://live.staticflickr.com/3033/3413933397_f7856c518d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414733756',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '8b23e99e2a',
#             'server': '3320',
#             'title': 'R0012475',
#             'url_q': 'https://live.staticflickr.com/3320/3414733756_8b23e99e2a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3414734662',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '78ae70df42',
#             'server': '3373',
#             'title': 'R0012476',
#             'url_q': 'https://live.staticflickr.com/3373/3414734662_78ae70df42_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4332817170',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '41650606@N06',
#             'secret': '245fb0a1a0',
#             'server': '2734',
#             'title': '완전 맛났어~~~',
#             'url_q': 'https://live.staticflickr.com/2734/4332817170_245fb0a1a0_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4362282117',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '24675118@N08',
#             'secret': 'db551ecabf',
#             'server': '4064',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '38513131402',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '118575432@N02',
#             'secret': '03af6e012a',
#             'server': '4519',
#             'title': '사랑하는 감성돔',
#             'url_q': 'https://live.staticflickr.com/4519/38513131402_03af6e012a_q.jpg',
#             'width_q': 150}],
#  'total': 610}

# %% [markdown]
# - 이미지 url로 이미지 저장
# - 2개 이상의 키워드로 플릭커에서 위의 코드를 이용하셔서 이미지를 수집해보세요.

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/707/23334959815_5b75a361fa_q.jpg
# 2:download= https://live.staticflickr.com/5803/22707816333_c7d4341133_q.jpg
# 3:download= https://live.staticflickr.com/5742/23039168170_61bdf06962_q.jpg
# 4:download= https://live.staticflickr.com/691/23226644172_61387ae009_q.jpg
# 5:download= https://live.staticflickr.com/602/22967036439_f4e529cde5_q.jpg
# 6:download= https://live.staticflickr.com/5809/23252384021_7431ff72c1_q.jpg
# 7:download= https://live.staticflickr.com/4054/4613588369_f20587cdc7_q.jpg
# 8:download= https://live.staticflickr.com/782/23226643962_eab85be54c_q.jpg
# 9:download= https://live.staticflickr.com/5722/23252388091_2cc79809cf_q.jpg
# 10:download= https://live.staticflickr.com/667/22967031779_bcf90a9c7a_q.jpg
# 11:download= https://live.staticflickr.com/5674/23039174230_e66e1039ec_q.jpg
# 12:download= https://live.staticflickr.com/610/23226644912_ff2544b0db_q.jpg
# 13:download= https://live.staticflickr.com/4071/4485897969_70ea22cb94_q.jpg
# 14:download= https://live.staticflickr.com/3089/2520058940_5f4d2bdd31_q.jpg
# 15:download= https://live.staticflickr.com/4050/4413988768_416d9b56c6_q.jpg
# 16:download= https://live.staticflickr.com/3833/12046800576_2b0ed02995_q.jpg
# 17:download= https://live.staticflickr.com/3705/12046843746_9b1342bf81_q.jpg
# 18:download= https://live.staticflickr.com/3304/3413917783_f272f490cb_q.jpg
# 19:download= https://live.staticflickr.com/146/364317848_beef335422_q.jpg
# 20:download= https://live.staticflickr.com/102/364317858_460dcce0e4_q.jpg
# 21:download= https://live.staticflickr.com/164/364317864_c67dacff6b_q.jpg
# 22:download= https://live.staticflickr.com/3713/12046009365_692b6624eb_q.jpg
# 23:download= https://live.staticflickr.com/2194/2519237785_da33b5ec91_q.jpg
# 24:download= https://live.staticflickr.com/2308/2384023607_8289b9e51b_q.jpg
# 25:download= https://live.staticflickr.com/2723/4427476755_b8ddc1ac07_q.jpg
# 26:download= https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg
# 27:download= https://live.staticflickr.com/2297/2123838912_218c6bfa54_q.jpg
# 28:download= https://live.staticflickr.com/3395/4561734849_da1878d0df_q.jpg
# 29:download= https://live.staticflickr.com/2743/5736664674_5543df9be6_q.jpg
# 30:download= https://live.staticflickr.com/3211/3027691038_eb80a3f1c8_q.jpg
# 31:download= https://live.staticflickr.com/6152/6174382207_22678f4664_q.jpg
# 32:download= https://live.staticflickr.com/3541/3414740364_7b0517f43b_q.jpg
# 33:download= https://live.staticflickr.com/3616/3414727600_d14ae5eaea_q.jpg
# 34:download= https://live.staticflickr.com/3605/3413932307_d9efd098fa_q.jpg
# 35:download= https://live.staticflickr.com/2404/2519237511_f8b5e17c3e_q.jpg
# 36:download= https://live.staticflickr.com/3561/3414728502_64c64d018d_q.jpg
# 37:download= https://live.staticflickr.com/3589/3413923087_38b0a8f7c3_q.jpg
# 38:download= https://live.staticflickr.com/3022/3414736660_f0fe1f53a0_q.jpg
# 39:download= https://live.staticflickr.com/3324/3414731218_13ccd5420a_q.jpg
# 40:download= https://live.staticflickr.com/3356/3414735588_eb051f117d_q.jpg
# 41:download= https://live.staticflickr.com/3564/3413935469_c7f53de2e5_q.jpg
# 42:download= https://live.staticflickr.com/3632/3413918637_80bded5c96_q.jpg
# 43:download= https://live.staticflickr.com/3664/3413926755_cf8716c918_q.jpg
# 44:download= https://live.staticflickr.com/3297/3414730260_2f344e871c_q.jpg
# 45:download= https://live.staticflickr.com/3033/3413933397_f7856c518d_q.jpg
# 46:download= https://live.staticflickr.com/3320/3414733756_8b23e99e2a_q.jpg
# 47:download= https://live.staticflickr.com/3373/3414734662_78ae70df42_q.jpg
# 48:download= https://live.staticflickr.com/2734/4332817170_245fb0a1a0_q.jpg
# 49:download= https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg
# 50:download= https://live.staticflickr.com/4519/38513131402_03af6e012a_q.jpg

# %%
#flick 사진 처리
import numpy as np
from PIL import Image
import os, glob, random

max_photo = 100
photo_size=32
x=[]
y=[]

files = glob.glob( "sushi"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(0)	#label을 0으로 지정


#이미지 출력
import matplotlib.pyplot as plt
idx = 0
plt.figure(figsize=(10,10))
for i in range(25):
 plt.subplot(5,5,i+1)
 plt.title(y[i+idx])
 plt.imshow(x[i+idx])
plt.show()

# %% [markdown]
#   - 두 번째 범주의 이미지 수집

# %%
wait_time=1

#사진 검색 및 저장
savedir="udon"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="우동", per_page=50, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 22,
#  'perpage': 50,
#  'photo': [{'farm': 1,
#             'height_q': 150,
#             'id': '338032189',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10976413@N00',
#             'secret': '3b9ff3c1ea',
#             'server': '148',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/148/338032189_3b9ff3c1ea_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6781197705',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '69329210@N02',
#             'secret': '2f44174835',
#             'server': '7174',
#             'title': '돈까스와 우동',
#             'url_q': 'https://live.staticflickr.com/7174/6781197705_2f44174835_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8906480455',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '21881584@N04',
#             'secret': 'dcb8e267d1',
#             'server': '8122',
#             'title': '마루가메 우동',
#             'url_q': 'https://live.staticflickr.com/8122/8906480455_dcb8e267d1_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '22707816013',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '121432267@N03',
#             'secret': 'aebcab61e9',
#             'server': '693',
#             'title': '우동 [うどん, udong]',
#             'url_q': 'https://live.staticflickr.com/693/22707816013_aebcab61e9_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5493823635',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '44393014@N04',
#             'secret': '46b99bfc51',
#             'server': '5135',
#             'title': '지명&우동',
#             'url_q': 'https://live.staticflickr.com/5135/5493823635_46b99bfc51_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33506964164',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '46558759@N00',
#             'secret': '3d884d2f6f',
#             'server': '2860',
#             'title': '어묵꼬치 우동',
#             'url_q': 'https://live.staticflickr.com/2860/33506964164_3d884d2f6f_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '34307783546',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '46558759@N00',
#             'secret': '90621704e4',
#             'server': '4157',
#             'title': '어묵꼬치 우동',
#             'url_q': 'https://live.staticflickr.com/4157/34307783546_90621704e4_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5494416182',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '44393014@N04',
#             'secret': '7c6388a3c8',
#             'server': '5097',
#             'title': '재성&우동',
#             'url_q': 'https://live.staticflickr.com/5097/5494416182_7c6388a3c8_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '335174197',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '27056886@N00',
#             'secret': '9b952dafa1',
#             'server': '143',
#             'title': '야채 튀김 우동',
#             'url_q': 'https://live.staticflickr.com/143/335174197_9b952dafa1_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8890527371',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '28021450@N05',
#             'secret': '6294495bf7',
#             'server': '7288',
#             'title': '홍연시장 포장마차 우동',
#             'url_q': 'https://live.staticflickr.com/7288/8890527371_6294495bf7_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '21984216894',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '28021450@N05',
#             'secret': '964813afff',
#             'server': '670',
#             'title': '우동 (백련시장 포장마차)',
#             'url_q': 'https://live.staticflickr.com/670/21984216894_964813afff_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '6925011722',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '67150137@N08',
#             'secret': 'cdb7fe3884',
#             'server': '5339',
#             'title': '2012.4.12-그림일기-불어튼 우동',
#             'url_q': 'https://live.staticflickr.com/5339/6925011722_cdb7fe3884_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5514441493',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '60353995@N05',
#             'secret': '8c5ebc75b7',
#             'server': '5055',
#             'title': '홍대 가미우동',
#             'url_q': 'https://live.staticflickr.com/5055/5514441493_8c5ebc75b7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '14621912731',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '124008426@N08',
#             'secret': '5b9f459f3f',
#             'server': '3864',
#             'title': '금요일 #볶음우동 #점심 #면 #우동',
#             'url_q': 'https://live.staticflickr.com/3864/14621912731_5b9f459f3f_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4267117871',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '56bd007a46',
#             'server': '4054',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/4054/4267117871_56bd007a46_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5809554197',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '53875604@N00',
#             'secret': '273b24b43b',
#             'server': '5273',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/5273/5809554197_273b24b43b_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5514442093',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '60353995@N05',
#             'secret': 'f845309610',
#             'server': '5013',
#             'title': '홍대 가미우동',
#             'url_q': 'https://live.staticflickr.com/5013/5514442093_f845309610_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2088296578',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '7828283@N04',
#             'secret': 'c4c4907696',
#             'server': '2258',
#             'title': 'SG102965',
#             'url_q': 'https://live.staticflickr.com/2258/2088296578_c4c4907696_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5674493249',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': 'f36ce06335',
#             'server': '5187',
#             'title': '은행동 마이야에서 먹은 고기..',
#             'url_q': 'https://live.staticflickr.com/5187/5674493249_f36ce06335_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '102978720',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '82971493@N00',
#             'secret': '5b4e40a41d',
#             'server': '32',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/32/102978720_5b4e40a41d_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8785727189',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': '037602ed47',
#             'server': '7455',
#             'title': '역전우동 0410',
#             'url_q': 'https://live.staticflickr.com/7455/8785727189_037602ed47_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8785727103',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': 'dfbbf97c96',
#             'server': '8546',
#             'title': '역전우동 0410',
#             'url_q': 'https://live.staticflickr.com/8546/8785727103_dfbbf97c96_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6314694856',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '937238328b',
#             'server': '6120',
#             'title': '유부우동',
#             'url_q': 'https://live.staticflickr.com/6120/6314694856_937238328b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '5764131137',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '32917190@N02',
#             'secret': 'a772ef33cd',
#             'server': '3421',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/3421/5764131137_a772ef33cd_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4082922476',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28909386@N06',
#             'secret': 'aaa415b3b0',
#             'server': '2607',
#             'title': '아내와 추억을 나누면 즐겁다..',
#             'url_q': 'https://live.staticflickr.com/2607/4082922476_aaa415b3b0_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '8796303382',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': '353478e31d',
#             'server': '3699',
#             'title': '역전우동 0410',
#             'url_q': 'https://live.staticflickr.com/3699/8796303382_353478e31d_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5263325054',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95206870@N00',
#             'secret': 'e81a6d8b51',
#             'server': '5081',
#             'title': '우동먹기',
#             'url_q': 'https://live.staticflickr.com/5081/5263325054_e81a6d8b51_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6389835481',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '73ef120b00',
#             'server': '6215',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/6215/6389835481_73ef120b00_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '5074123717',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '32322221@N06',
#             'secret': '8d99578d01',
#             'server': '4036',
#             'title': '우동,,,',
#             'url_q': 'https://live.staticflickr.com/4036/5074123717_8d99578d01_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5515036936',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '60353995@N05',
#             'secret': '2dfaf404aa',
#             'server': '5214',
#             'title': '홍대 가미우동',
#             'url_q': 'https://live.staticflickr.com/5214/5515036936_2dfaf404aa_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '8785727035',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': '2370bd4392',
#             'server': '3762',
#             'title': '역전우동 0410',
#             'url_q': 'https://live.staticflickr.com/3762/8785727035_2370bd4392_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4437359342',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27097317@N00',
#             'secret': '5c330aced8',
#             'server': '4044',
#             'title': '규동과 미니우동',
#             'url_q': 'https://live.staticflickr.com/4044/4437359342_5c330aced8_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3203547600',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '26991826@N03',
#             'secret': 'c1362294b9',
#             'server': '3081',
#             'title': '우동을 배달 시키니 이래 갖..',
#             'url_q': 'https://live.staticflickr.com/3081/3203547600_c1362294b9_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5494415020',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '44393014@N04',
#             'secret': 'e7992db1fe',
#             'server': '5293',
#             'title': '우동그릇',
#             'url_q': 'https://live.staticflickr.com/5293/5494415020_e7992db1fe_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5494415654',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '44393014@N04',
#             'secret': '084b06133a',
#             'server': '5055',
#             'title': '우동그릇2',
#             'url_q': 'https://live.staticflickr.com/5055/5494415654_084b06133a_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6177009495',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '82c2c2754d',
#             'server': '6178',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/6178/6177009495_82c2c2754d_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '45002245594',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '85d0e4df47',
#             'server': '1959',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/1959/45002245594_85d0e4df47_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4562354637',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '25292648@N05',
#             'secret': '708e2ac553',
#             'server': '4023',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/4023/4562354637_708e2ac553_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '45002247434',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'e0db24de23',
#             'server': '1902',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/1902/45002247434_e0db24de23_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3021179593',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '08f2df261c',
#             'server': '3025',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/3025/3021179593_08f2df261c_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45727411811',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'a54500c884',
#             'server': '4912',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/4912/45727411811_a54500c884_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '44813341995',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'c922ac348b',
#             'server': '4808',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/4808/44813341995_c922ac348b_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5528079410',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'e3b35e8d47',
#             'server': '5177',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/5177/5528079410_e3b35e8d47_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45002243584',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '654f467d07',
#             'server': '4846',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/4846/45002243584_654f467d07_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3538926830',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29904101@N08',
#             'secret': 'b46dc1ef6a',
#             'server': '3584',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/3584/3538926830_b46dc1ef6a_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45727401541',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '144372879a',
#             'server': '4803',
#             'title': '남가좌동 가타쯔무리',
#             'url_q': 'https://live.staticflickr.com/4803/45727401541_144372879a_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4744208863',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '4b2469552c',
#             'server': '4119',
#             'title': '우동',
#             'url_q': 'https://live.staticflickr.com/4119/4744208863_4b2469552c_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7714650882',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50342736@N02',
#             'secret': '2d3e3d1efc',
#             'server': '7137',
#             'title': '우동!!',
#             'url_q': 'https://live.staticflickr.com/7137/7714650882_2d3e3d1efc_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4350817770',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '46056362@N03',
#             'secret': '0ce4ef8796',
#             'server': '2711',
#             'title': 'Sample_032',
#             'url_q': 'https://live.staticflickr.com/2711/4350817770_0ce4ef8796_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5263324228',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95206870@N00',
#             'secret': '60ac8e7901',
#             'server': '5169',
#             'title': '우동먹기',
#             'url_q': 'https://live.staticflickr.com/5169/5263324228_60ac8e7901_q.jpg',
#             'width_q': 150}],
#  'total': 1070}

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/148/338032189_3b9ff3c1ea_q.jpg
# 2:download= https://live.staticflickr.com/7174/6781197705_2f44174835_q.jpg
# 3:download= https://live.staticflickr.com/8122/8906480455_dcb8e267d1_q.jpg
# 4:download= https://live.staticflickr.com/693/22707816013_aebcab61e9_q.jpg
# 5:download= https://live.staticflickr.com/5135/5493823635_46b99bfc51_q.jpg
# 6:download= https://live.staticflickr.com/2860/33506964164_3d884d2f6f_q.jpg
# 7:download= https://live.staticflickr.com/4157/34307783546_90621704e4_q.jpg
# 8:download= https://live.staticflickr.com/5097/5494416182_7c6388a3c8_q.jpg
# 9:download= https://live.staticflickr.com/143/335174197_9b952dafa1_q.jpg
# 10:download= https://live.staticflickr.com/7288/8890527371_6294495bf7_q.jpg
# 11:download= https://live.staticflickr.com/670/21984216894_964813afff_q.jpg
# 12:download= https://live.staticflickr.com/5339/6925011722_cdb7fe3884_q.jpg
# 13:download= https://live.staticflickr.com/5055/5514441493_8c5ebc75b7_q.jpg
# 14:download= https://live.staticflickr.com/3864/14621912731_5b9f459f3f_q.jpg
# 15:download= https://live.staticflickr.com/4054/4267117871_56bd007a46_q.jpg
# 16:download= https://live.staticflickr.com/5273/5809554197_273b24b43b_q.jpg
# 17:download= https://live.staticflickr.com/5013/5514442093_f845309610_q.jpg
# 18:download= https://live.staticflickr.com/2258/2088296578_c4c4907696_q.jpg
# 19:download= https://live.staticflickr.com/5187/5674493249_f36ce06335_q.jpg
# 20:download= https://live.staticflickr.com/32/102978720_5b4e40a41d_q.jpg
# 21:download= https://live.staticflickr.com/7455/8785727189_037602ed47_q.jpg
# 22:download= https://live.staticflickr.com/8546/8785727103_dfbbf97c96_q.jpg
# 23:download= https://live.staticflickr.com/6120/6314694856_937238328b_q.jpg
# 24:download= https://live.staticflickr.com/3421/5764131137_a772ef33cd_q.jpg
# 25:download= https://live.staticflickr.com/2607/4082922476_aaa415b3b0_q.jpg
# 26:download= https://live.staticflickr.com/3699/8796303382_353478e31d_q.jpg
# 27:download= https://live.staticflickr.com/5081/5263325054_e81a6d8b51_q.jpg
# 28:download= https://live.staticflickr.com/6215/6389835481_73ef120b00_q.jpg
# 29:download= https://live.staticflickr.com/4036/5074123717_8d99578d01_q.jpg
# 30:download= https://live.staticflickr.com/5214/5515036936_2dfaf404aa_q.jpg
# 31:download= https://live.staticflickr.com/3762/8785727035_2370bd4392_q.jpg
# 32:download= https://live.staticflickr.com/4044/4437359342_5c330aced8_q.jpg
# 33:download= https://live.staticflickr.com/3081/3203547600_c1362294b9_q.jpg
# 34:download= https://live.staticflickr.com/5293/5494415020_e7992db1fe_q.jpg
# 35:download= https://live.staticflickr.com/5055/5494415654_084b06133a_q.jpg
# 36:download= https://live.staticflickr.com/6178/6177009495_82c2c2754d_q.jpg
# 37:download= https://live.staticflickr.com/1959/45002245594_85d0e4df47_q.jpg
# 38:download= https://live.staticflickr.com/4023/4562354637_708e2ac553_q.jpg
# 39:download= https://live.staticflickr.com/1902/45002247434_e0db24de23_q.jpg
# 40:download= https://live.staticflickr.com/3025/3021179593_08f2df261c_q.jpg
# 41:download= https://live.staticflickr.com/4912/45727411811_a54500c884_q.jpg
# 42:download= https://live.staticflickr.com/4808/44813341995_c922ac348b_q.jpg
# 43:download= https://live.staticflickr.com/5177/5528079410_e3b35e8d47_q.jpg
# 44:download= https://live.staticflickr.com/4846/45002243584_654f467d07_q.jpg
# 45:download= https://live.staticflickr.com/3584/3538926830_b46dc1ef6a_q.jpg
# 46:download= https://live.staticflickr.com/4803/45727401541_144372879a_q.jpg
# 47:download= https://live.staticflickr.com/4119/4744208863_4b2469552c_q.jpg
# 48:download= https://live.staticflickr.com/7137/7714650882_2d3e3d1efc_q.jpg
# 49:download= https://live.staticflickr.com/2711/4350817770_0ce4ef8796_q.jpg
# 50:download= https://live.staticflickr.com/5169/5263324228_60ac8e7901_q.jpg

# %%
#flick 사진 처리
max_photo = 100
photo_size=32

files = glob.glob( "udon"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(1)	#label을 0으로 지정


#이미지 출력
import matplotlib.pyplot as plt
idx = 0
plt.figure(figsize=(10,10))
for i in range(25):
 plt.subplot(5,5,i+1)
 plt.title(y[i+idx])
 plt.imshow(x[i+idx])
plt.show()

# %%
x = np.array(x)
y = np.array(y)
x.shape
y.shape
# Out:
# (100,)

# %% [markdown]
# 3. DNN 적용하기

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split

num_classes = 2
im_rows = 32
im_cols = 32
im_size = im_rows * im_cols * 3

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# %%
# 데이터를 1차원 배열로 변환하기
X_train = X_train.reshape(-1, im_size).astype('float32') / 255 #평탄화->소숫점있는숫자->스케일링
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# 타겟변수를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

X_train.shape
y_train.shape
# Out:
# (70, 2)

# %%
#실행 전 GPU 설정
# 모델 정의하기
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(im_size,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=10,
    verbose=1,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 1s 142ms/step - loss: 1.8992 - accuracy: 0.6286 - val_loss: 1.0784 - val_accuracy: 0.3000
# Epoch 2/10
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6762 - accuracy: 0.5143 - val_loss: 0.6195 - val_accuracy: 0.6667
# Epoch 3/10
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7934 - accuracy: 0.4857 - val_loss: 1.4957 - val_accuracy: 0.3000
# Epoch 4/10
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7178 - accuracy: 0.5857 - val_loss: 0.6477 - val_accuracy: 0.6333
# Epoch 5/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6104 - accuracy: 0.6429 - val_loss: 0.7188 - val_accuracy: 0.5667
# Epoch 6/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5352 - accuracy: 0.7429 - val_loss: 1.3823 - val_accuracy: 0.3667
# Epoch 7/10
# 3/3 [==============================] - 0s 31ms/step - loss: 0.4750 - accuracy: 0.7571 - val_loss: 0.7084 - val_accuracy: 0.6333
# Epoch 8/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4133 - accuracy: 0.8143 - val_loss: 1.1014 - val_accuracy: 0.4000
# Epoch 9/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3324 - accuracy: 0.8571 - val_loss: 1.0964 - val_accuracy: 0.4667
# Epoch 10/10
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2880 - accuracy: 0.9143 - val_loss: 0.9190 - val_accuracy: 0.6333

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9190 - accuracy: 0.6333
# 정답률= 0.6333333253860474 loss= 0.9190400242805481

# %%
# 학습 상태를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# 4. CNN 적용하기

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

num_classes = 10
im_rows = 32
im_cols = 32
in_shape = (im_rows, im_cols, 3)

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# 데이터를 정규화하기 (flatten을 하지 않음)
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# 모델 정의하기
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same', input_shape=in_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))

# %%
#실행 전 GPU 설정
# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=10,
    verbose=1,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 2s 329ms/step - loss: 1.8350 - accuracy: 0.5143 - val_loss: 0.9040 - val_accuracy: 0.4333
# Epoch 2/10
# 3/3 [==============================] - 1s 260ms/step - loss: 0.8264 - accuracy: 0.4571 - val_loss: 0.6962 - val_accuracy: 0.4333
# Epoch 3/10
# 3/3 [==============================] - 1s 160ms/step - loss: 0.6734 - accuracy: 0.5857 - val_loss: 0.8864 - val_accuracy: 0.4333
# Epoch 4/10
# 3/3 [==============================] - 1s 247ms/step - loss: 0.7363 - accuracy: 0.5571 - val_loss: 0.6602 - val_accuracy: 0.5667
# Epoch 5/10
# 3/3 [==============================] - 1s 167ms/step - loss: 0.6887 - accuracy: 0.5714 - val_loss: 0.7656 - val_accuracy: 0.4333
# Epoch 6/10
# 3/3 [==============================] - 1s 167ms/step - loss: 0.6641 - accuracy: 0.6143 - val_loss: 0.5436 - val_accuracy: 0.7667
# Epoch 7/10
# 3/3 [==============================] - 1s 178ms/step - loss: 0.6417 - accuracy: 0.6000 - val_loss: 0.5352 - val_accuracy: 0.8667
# Epoch 8/10
# 3/3 [==============================] - 1s 230ms/step - loss: 0.5696 - accuracy: 0.7000 - val_loss: 0.5476 - val_accuracy: 0.7000
# Epoch 9/10
# 3/3 [==============================] - 1s 179ms/step - loss: 0.5671 - accuracy: 0.6857 - val_loss: 0.6125 - val_accuracy: 0.5667
# Epoch 10/10
# 3/3 [==============================] - 1s 190ms/step - loss: 0.5246 - accuracy: 0.7429 - val_loss: 0.5376 - val_accuracy: 0.8667

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 1/1 [==============================] - 0s 79ms/step - loss: 0.5376 - accuracy: 0.8667
# 정답률= 0.8666666746139526 loss= 0.5375728607177734
