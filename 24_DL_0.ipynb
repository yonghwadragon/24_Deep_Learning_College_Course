# %%
# !pip install flickrapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.7 MB/s eta 0:00:00
# ...

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys
from google.colab import userdata


key="cee8e2db7cb3b5062d02870f0cf2e562"
secret=userdata.get('secret_flickrapi')

wait_time=1

#사진 검색 및 저장
savedir="dog"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="dog", per_page=50, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 8256,
#  'perpage': 50,
#  'photo': [{'farm': 66,
#             'height_q': 150,
#             'id': '32598752764',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '58130019@N08',
#             'secret': 'c10a7ff6ee',
#             'server': '65535',
#             'title': 'Dog',
#             'url_q': 'https://live.staticflickr.com/65535/32598752764_c10a7ff6ee_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '44926777104',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '160167872@N05',
#             'secret': '8a6e553a48',
#             'server': '1923',
#             'title': 'Dog',
#             'url_q': 'https://live.staticflickr.com/1923/44926777104_8a6e553a48_q.jpg',
#             'width_q': 150},
# ...

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/65535/32598752764_c10a7ff6ee_q.jpg
# 2:download= https://live.staticflickr.com/1923/44926777104_8a6e553a48_q.jpg
# 3:download= https://live.staticflickr.com/3910/15131237412_268a1e41a3_q.jpg
# 4:download= https://live.staticflickr.com/5608/15479778255_c7eb157180_q.jpg
# 5:download= https://live.staticflickr.com/8201/8193537196_65aaf6107f_q.jpg
# 6:download= https://live.staticflickr.com/1643/25989424636_2bb1afe859_q.jpg
# 7:download= https://live.staticflickr.com/4148/5022927104_515e808b66_q.jpg
# 8:download= https://live.staticflickr.com/1613/24066106230_5169269428_q.jpg
# 9:download= https://live.staticflickr.com/580/33326250781_65fa0a0887_q.jpg
# 10:download= https://live.staticflickr.com/3005/2699088006_85e58eb619_q.jpg
# 11:download= https://live.staticflickr.com/4063/4652502241_c101591a93_q.jpg
# 12:download= https://live.staticflickr.com/868/41099654691_c42fcde81b_q.jpg
# ...

# %%
#flick 사진 처리
import numpy as np
from PIL import Image
import os, glob, random

max_photo = 100
photo_size=32
x=[]
y=[]

files = glob.glob( "dog"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(0)	#label을 0으로 지정


#이미지 출력
import matplotlib.pyplot as plt
idx = 0
plt.figure(figsize=(10,10))
for i in range(25):
 plt.subplot(5,5,i+1)
 plt.title(y[i+idx])
 plt.imshow(x[i+idx])
plt.show()

# %%
wait_time=1

#사진 검색 및 저장
savedir="cat"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="cat", per_page=50, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 9453,
#  'perpage': 50,
#  'photo': [{'farm': 6,
#             'height_q': 150,
#             'id': '14934282524',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27409143@N00',
#             'secret': '344c84246b',
#             'server': '5598',
#             'title': 'Cat',
#             'url_q': 'https://live.staticflickr.com/5598/14934282524_344c84246b_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45925416992',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '73422502@N08',
#             'secret': 'c9caac8cb9',
#             'server': '4838',
#             'title': 'Cat',
#             'url_q': 'https://live.staticflickr.com/4838/45925416992_c9caac8cb9_q.jpg',
#             'width_q': 150},
# ...

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/5598/14934282524_344c84246b_q.jpg
# 2:download= https://live.staticflickr.com/4838/45925416992_c9caac8cb9_q.jpg
# 3:download= https://live.staticflickr.com/5213/5508784414_d2d84f9c92_q.jpg
# 4:download= https://live.staticflickr.com/8750/16386660144_a6c4026657_q.jpg
# 5:download= https://live.staticflickr.com/7210/6843831417_861d6996e8_q.jpg
# 6:download= https://live.staticflickr.com/2813/32711702733_7cdd9dbb3a_q.jpg
# 7:download= https://live.staticflickr.com/7302/11991979753_eac1d33dd8_q.jpg
# 8:download= https://live.staticflickr.com/4728/39256672581_c48569e3a2_q.jpg
# 9:download= https://live.staticflickr.com/7073/7190755946_ea97e85765_q.jpg
# 10:download= https://live.staticflickr.com/267/31671889412_bb37b917be_q.jpg
# 11:download= https://live.staticflickr.com/4066/4638426067_1a979d3690_q.jpg
# 12:download= https://live.staticflickr.com/4182/33871494874_dce6b5154b_q.jpg
# ...

# %%
#flick 사진 처리
max_photo = 100
photo_size=32

files = glob.glob( "cat"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(1)	#label을 0으로 지정


# 이미지를 섞어 고양이 이미지만 출력하도록 설정
cat_indices = [i for i, label in enumerate(y) if label == 1]
random.shuffle(cat_indices)

# 고양이 이미지 출력
plt.figure(figsize=(10,10))
for i in range(25):
    if i < len(cat_indices):
        plt.subplot(5,5,i+1)
        plt.title(y[cat_indices[i]])
        plt.imshow(x[cat_indices[i]])
plt.show()

# %%
x = np.array(x)
y = np.array(y)
x.shape
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split

num_classes = 2
im_rows = 32
im_cols = 32
im_size = im_rows * im_cols * 3

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# %%
# 데이터를 1차원 배열로 변환하기
X_train = X_train.reshape(-1, im_size).astype('float32') / 255 #평탄화->소숫점있는숫자->스케일링
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# 타겟변수를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

X_train.shape
y_train.shape
# Out:
# (70, 2)

# %% [markdown]
# # DNN  xxxxxxxxxxxxxxxxxx

# %%
#실행 전 GPU 설정
# 모델 정의하기
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(im_size,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=10,
    verbose=1,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 4s 481ms/step - loss: 0.7691 - accuracy: 0.4857 - val_loss: 0.7557 - val_accuracy: 0.5000
# Epoch 2/10
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6809 - accuracy: 0.5429 - val_loss: 0.7153 - val_accuracy: 0.4667
# Epoch 3/10
# 3/3 [==============================] - 0s 81ms/step - loss: 0.6532 - accuracy: 0.5571 - val_loss: 0.7805 - val_accuracy: 0.4333
# Epoch 4/10
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6683 - accuracy: 0.6143 - val_loss: 0.7410 - val_accuracy: 0.4667
# Epoch 5/10
# 3/3 [==============================] - 0s 46ms/step - loss: 0.5682 - accuracy: 0.7000 - val_loss: 0.7676 - val_accuracy: 0.4333
# Epoch 6/10
# 3/3 [==============================] - 0s 55ms/step - loss: 0.5634 - accuracy: 0.7000 - val_loss: 0.9445 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9770 - accuracy: 0.4000
# 정답률= 0.4000000059604645 loss= 0.9770122766494751

# %%
# 학습 상태를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # CNN

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

num_classes = 10
im_rows = 32
im_cols = 32
in_shape = (im_rows, im_cols, 3)

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# 데이터를 정규화하기 (flatten을 하지 않음)
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# 모델 정의하기
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same', input_shape=in_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))

# %%
#실행 전 GPU 설정
# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=100,
    verbose=1,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 300ms/step - loss: 1.0268 - accuracy: 0.7571 - val_loss: 1.7696 - val_accuracy: 0.6667
# Epoch 2/100
# 3/3 [==============================] - 1s 166ms/step - loss: 0.4043 - accuracy: 0.7714 - val_loss: 2.0616 - val_accuracy: 0.6000
# Epoch 3/100
# 3/3 [==============================] - 1s 166ms/step - loss: 0.1337 - accuracy: 0.9571 - val_loss: 0.8140 - val_accuracy: 0.6000
# Epoch 4/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.7066 - val_accuracy: 0.6667
# Epoch 5/100
# 3/3 [==============================] - 0s 145ms/step - loss: 0.0822 - accuracy: 1.0000 - val_loss: 0.8076 - val_accuracy: 0.6667
# Epoch 6/100
# 3/3 [==============================] - 1s 160ms/step - loss: 0.1544 - accuracy: 0.9429 - val_loss: 0.7965 - val_accuracy: 0.6667
# Epoch 7/100
# ...

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 1/1 [==============================] - 0s 236ms/step - loss: 1.1779 - accuracy: 0.6000
# 정답률= 0.6000000238418579 loss= 1.1778641939163208

# %%
# 학습 상태를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# 전처리 함수 정의
def preprocess_image(image_path, image_size):
    img = Image.open(image_path)
    img = img.convert("RGB")
    img = img.resize((image_size, image_size))
    img = np.asarray(img)
    img = img.astype('float32') / 255
    img = np.expand_dims(img, axis=0)  # 모델 입력 형태로 맞춤
    return img

# 사람 얼굴 이미지 경로
person_image_path = "yonghwa_1.jpg"

# 이미지 전처리
photo_size = 32  # 기존 모델에서 사용한 이미지 크기
person_image = preprocess_image(person_image_path, photo_size)

# 모델 예측
prediction = model.predict(person_image)

# 예측 결과 출력
class_names = ["Cat-like", "Dog-like"]
predicted_class = class_names[np.argmax(prediction)]
print("Prediction (Cat-like or Dog-like):", predicted_class)
print("Confidence Scores:", prediction)

# 시각화
plt.imshow(np.squeeze(person_image))
plt.title(predicted_class)
plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# Prediction (Cat-like or Dog-like): Dog-like
# Confidence Scores: [[2.50974414e-03 9.97490287e-01 2.58836531e-14 7.39445507e-21
#   3.77832973e-11 9.32069873e-12 3.56461305e-09 2.32431717e-16
#   6.47488009e-12 1.12109046e-13]]
