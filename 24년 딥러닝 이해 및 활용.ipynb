# %% [markdown]
# 3월 5일 \
# OT \
# 유행은 지났다. \
# 4학년 수업. 인공신경망. Ax(인공지능 변환), Dx(디지털 변환) \
# 딥러닝을 위한 수학 리뷰 부터 쭉쭉, 발표시 인공신경망 성능 좋은 사람 굿 \
# 텐서플로 파이토치 여기서는 텐서플로로 한다. 파이토치가 좋은것 같지만 나중에 보기 \

# %% [markdown]
# 3월 12일 \
# 실습

# %% [markdown]
# 3월 13일 \
# 일단 수업

# %% [markdown]
# 3월 19일 \
# 일단 수업

# %% [markdown]
# 3월 20일 \
# ROI 돈 어떻게 벌까? BM 비지니스 모델을 잘 하자. \
# 신뢰할 수 있는 AI, 즉, XAI 설명 할 수 있어야한다. \
# 오버샘플링 : 데이터가 작아서 비슷한거 뽑아내는 것 데이터 합성 \

# %% [markdown]
# 3월 26일 \
# 실습 \
# 28칸 * 28칸 하나의 이미지있고 각 라벨이 있습니다. 이게 엄청 많습니다. \
# 이미지 하나를 한줄로 만듭니다. 라벨 하나를 1이라고 하면 다른 것은 0이라고 둘 수 있다. \
# 예시로 3행 3열이 9개 있으면 3행 3열을 한줄로 만들어서 9열로 만들고 이게 9개가 있는 것이다.

# %% [markdown]
# 3월 27일 \
# 어제 실습 수업 시작, 이론 수업 함 다음부터는 실습 위주로

# %% [markdown]
# 4월 2일 \
# 숫자 크기 원핫인코딩 ANN 이미지 테그트 소리 냄새 Xs y \
# 이미지 -> pixel 단위로 표현 \
# 0~255 높으면 진함. 라벨을 동그라미, 세모, 네모 등 지정 가능. 이게 나중에 cnn이랑 연결됨 \
#
# 이미지의 크기가 다 같아야 한다. 만약 이미지 크기가 다 다르면 맞추어야함. \
# 한줄로 만들고 라벨을 붙혀준다. 다시 이미지를 원래대로 왔다갔다 가능하다. \
# iot 랑 ai랑 합쳐서 aiot \
# 이러한 기법을 데이터를 센싱해서 학습에서 어디에 쓰는 것이 좋을 지 공모전 같은 곳에서 \
# RGB라고 컴퓨터에서는 3가지로 모든 색을 표현합니다. \
# 어느 그림에 R에 대한 0~255 G랑 B도 표현 합니다. \
# 위의 R을 한줄로 G도 B도 한 즐로 만들고 다 잇는다. \
# 피쳐가 많아도 문제가 되지 않는다 계산은 컴퓨터가 한다. \

# %% [markdown]
# 4월 3일 \
# 수업

# %% [markdown]
# 4월 9일 \
# 수업 \
# 데이터 셋 : https://archive.ics.uci.edu/datasets \
# 오버샘플링 가짜를 뻥튀기 \
# 언더샘플링 많은 진짜를 줄이는 방법 \

# %% [markdown]
# 4월 10일 \
# 오늘 선거일이라 쉬지만 영상보기 5주차 \
# 로그가 중요해 데이터 분석도 해주고 보통 텍스트 파일이다. \
# 문제가 생기고 볼 수 있으며 관리 할 수도 있다. \
#
# % 명령어는 파이썬 명령어도 아니고 OS 명령어도 아닌 주피터 노트북 자체의 명령어 \

# %% [markdown]
# 4월 16일 \
# 실습은 batchnomarnazation? 이거 하나면 되서 이론만 있음. \
# 배치 노말라이제이션() 이거는 무조건 시험 \
# IDBAD

# %% [markdown]
# 4월 17일 \
# 중간 정리

# %% [markdown]
# 4월 30일 \
# 수업

# %% [markdown]
# 5월 7일 \
# 실습 이고 곧 과제 하기만 하면 된다.

# %% [markdown]
# 5월 8일 \
# 수업

# %% [markdown]
# 5월 14일 \
# 수업

# %% [markdown]
# 5월 21일 \
# 실습 수업
